# %%
import lasio
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import lasio

df=lasio.read(r"C:\Users\absid\Downloads\FM_PRESS_RAW_RUN8_MWD_1.LAS").df()

# %%
df.head()
# Out:
#        DD_PRESS  DD_VOLUME    TEMP  DD_PRESS_MOD_1000  DD_PRESS_MOD_100  \
# TIME
# 2.1   425.23761        0.0  84.938            425.238           25.2376
# 2.2   425.24883        0.0  84.940            425.249           25.2488
# 2.3   425.24352        0.0  84.943            425.244           25.2435
# 2.4   425.22410        0.0  84.943            425.224           25.2241
# 2.5   425.16936        0.0  84.939            425.169           25.1694
#
#       DD_PRESS_MOD_10  DD_PRESS_MOD_1  DD_PRESS_MOD_01  DD_PRESS_MOD_001  \
# TIME
# 2.1           5.23761        0.237610         0.037610          0.007610
# 2.2           5.24883        0.248834         0.048834          0.008834
# 2.3           5.24352        0.243516         0.043516          0.003516
# 2.4           5.22410        0.224095         0.024095          0.004095
# 2.5           5.16936        0.169363         0.069363          0.009363
#
#       DD_PRESS_MOD_0001
# TIME
# 2.1            0.000610
# ...

# %%
df=df.reset_index()

# %%
df.columns
# Out:
# Index(['TIME', 'DD_PRESS', 'DD_VOLUME', 'TEMP', 'DD_PRESS_MOD_1000',
#        'DD_PRESS_MOD_100', 'DD_PRESS_MOD_10', 'DD_PRESS_MOD_1',
#        'DD_PRESS_MOD_01', 'DD_PRESS_MOD_001', 'DD_PRESS_MOD_0001'],
#       dtype='object')

# %%
df=df.drop(columns=['DD_PRESS_MOD_1000',
       'DD_PRESS_MOD_100', 'DD_PRESS_MOD_10', 'DD_PRESS_MOD_1',
       'DD_PRESS_MOD_01', 'DD_PRESS_MOD_001', 'DD_PRESS_MOD_0001'])

# %%
df.sample(10)
# Out:
#        TIME   DD_PRESS  DD_VOLUME    TEMP
# 160    18.1  425.32569    0.00000  84.930
# 512    53.3  346.42156   10.52664  84.875
# 1315  133.6  346.40303   29.43087  84.859
# 44      6.5  425.24406    0.00000  84.938
# 1518  153.9  425.58627    0.00000  84.891
# 1461  148.2  425.50326    0.00000  84.862
# 808    82.9  346.38289   19.72014  84.859
# 1207  122.8  346.40234   29.43087  84.857
# 827    84.8  346.40708   19.72014  84.859
# 457    47.8  346.41459   10.52664  84.875

# %%
sns.pairplot(df)

# %%
df.corr().transpose()
# Out:
#                TIME  DD_PRESS  DD_VOLUME      TEMP
# TIME       1.000000 -0.062163   0.366616 -0.633156
# DD_PRESS  -0.062163  1.000000  -0.747719  0.748582
# DD_VOLUME  0.366616 -0.747719   1.000000 -0.760107
# TEMP      -0.633156  0.748582  -0.760107  1.000000

# %%
import plotly.express as px

# Assuming df is your DataFrame containing the data

# Create line plot
fig = px.line(df, x='DD_PRESS', y='TIME', template='plotly_dark')

fig.update_yaxes(autorange="reversed")

fig.update_layout(width=400, height=900)


fig.show()

# %%
import plotly.express as px

# Assuming df is your DataFrame containing the data

# Create line plot
fig = px.line(df, x='DD_VOLUME', y='TIME', template='plotly_dark')

fig.update_yaxes(autorange="reversed")

fig.update_layout(width=400, height=900)


fig.show()

# %%
import plotly.express as px

# Assuming df is your DataFrame containing the data

# Create line plot
fig = px.line(df, x='TEMP', y='TIME', template='plotly_dark')

fig.update_yaxes(autorange="reversed")

fig.update_layout(width=400, height=900)


fig.show()
